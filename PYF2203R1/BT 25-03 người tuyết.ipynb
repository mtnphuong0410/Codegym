# %%
import turtle 
t=turtle.Turtle()
t.speed(0)
#t.hideturtle()

screen = t.getscreen()
screen.bgcolor("powderblue")

t.penup()
t.backward (100)
t.right(90)
t.fd(100)
t.pendown()

#mình người tuyết 
t.begin_fill()
t.color("floralwhite","white")
t.circle(150)
t.end_fill()

t.penup()
t.left(90)
t.fd(150)
t.left(90)
t.fd(100)
t.right(90)
t.pendown()

#đầu ng tuyết 
t.begin_fill()
t.color("floralwhite","white")
t.circle(100)
t.end_fill()

t.penup()
t.left(90)
t.fd(125)
t.right(90)
t.fd(50)
t.left(90)
t.pendown()

#mắt 
t.begin_fill()
t.color ("black","black")
t.pensize(5)
t.circle(15,180)

t.penup()
t.right(90)
t.fd(40)
t.pendown()
t.right(90)
t.circle(15,180)

t.penup()
t.left(90)
t.fd(50)
t.right(90)
t.fd(30)
t.pendown()

#mũi
t.begin_fill()
t.color("red","red")
t.circle(9)
t.end_fill()

t.penup()
t.right(90)
t.fd(50)
t.left(90)
t.fd(5)
t.left(30)
t.fd(25)
t.pendown()

#miệng
t.begin_fill()
t.color("black")
t.circle(50, 120)
t.end_fill()

t.penup()
t.fd(30)
t.pendown()

#má
t.begin_fill()
t.color ("pink","pink")
t.circle(5)
t.end_fill()

t.penup()
t.begin_fill()
t.color ("pink","pink")
t.left(120)
t.fd(110)
t.right(90)
t.pendown()
t.circle(5)
t.end_fill()

#chân nón
t.penup()
t.left(90)
t.fd(45)
t.right(90)
t.fd(50)
t.right(80)
t.pendown()
t.begin_fill()
t.color("floralwhite","crimson")
t.fd(150)
t.circle(15,180)
t.fd(150)
t.circle(15,180)
t.end_fill()

#thân nón
t.penup()
t.left(90)
t.fd(33)
t.right(90)
t.pendown()
t.begin_fill()
t.color("floralwhite","crimson")
t.fd(150)
t.left(120)
t.fd(100)
t.circle(30,120)
t.fd(100)
t.end_fill()

t.penup()
t.left(180)
t.right(170)
t.fd(190)
t.left(90)
t.fd(15)
t.left(150)
t.pendown()

#tay trái 
t.pensize(7)
t.begin_fill()
t.color("saddlebrown","saddlebrown")
t.fd(70)
t.right(50)
t.fd(90)
t.left(180)
t.fd(25)
t.right(130)
t.pensize(5)
t.fd(30)
t.left(180)
t.fd(30)
t.left(310)
t.fd(15)
t.left(140)
t.fd(40)
t.penup()
t.left(270)
t.fd(200)
t.left(47)
t.fd(105)
t.left(20)
t.pendown()

#tay phải
t.pensize(7)
t.fd(50)
t.left(45)
t.fd(100)
t.pensize(5)
t.left(180)
t.fd(25)
t.right(130)
t.fd(30)
t.left(180)
t.fd(30)
t.left(310)
t.fd(15)
t.left(140)
t.fd(40)
t.penup()
t.left(180)
t.fd(250)
t.left(57)
t.fd(40)
t.pendown()
t.begin_fill()
t.color("black","black")
t.circle(10)
t.penup()
t.fd(50)
t.pendown()
t.circle(10)
t.penup()
t.fd(50)
t.pendown()
t.circle(10)
t.end_fill()
t.penup()
t.left(180)
t.fd(190)
t.left(90)
t.fd(95)
t.left(180)
t.pendown()
t.pensize(35)
t.begin_fill()
t.color("crimson","red")
t.fd(190)
t.left(180)
t.pensize(20)
t.fd(10)
t.left(90)
t.fd(150)
t.left(180)
t.fd(150)
t.left(90)
t.fd(30)
t.left(90)
t.fd(80)
t.penup()
t.fd(200)
t.left(90)
t.fd(100)
t.left(130)
t.fd(700)
t.pendown()
